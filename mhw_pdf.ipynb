# %%
from reportlab.pdfgen import canvas
from reportlab.lib.pagesizes import A4
import os 
from tkinter import *
from tkinter import ttk
from tkinter import messagebox
import time

# %%
pastaApp=os.path.dirname('/Users/Daniela/Documents/TRIATLAS/') #localque salva

# %%
def mp(mm):
    return mm/0.352777 #calcula os pontos em milimetros

# %%
def criarPDF(): 
    cnv= canvas.Canvas(pastaApp+"\\MHW.pdf", pagesize=A4) #nome do arquivo
    
    cnv.drawString(mp(70),mp(250),"MHW events in the North Atlantic Ocean") #posição x e y no pdf 
    cnv.setFont('Helvetica', 12)
    
    cnv.drawImage(pastaApp+"\\mhw_category.jpg", 70, 300, width=500, height=300)
    cnv.save()
    print()

# %%
app=Tk()
app.title("MHW")
app.geometry("600x450")
# Out:
# ''

# %%
btn_criarPDF =Button(app,text="Criar PDF",command=criarPDF)
btn_criarPDF.pack(side="left",padx=10)

# %%
app.mainloop()
